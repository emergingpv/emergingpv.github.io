# %% [markdown]
# Table 1. List of certified single-junction record cells under global AM1.5 spectrum (1000 W/m$^{2}$)at 25$^{\circ}$ C, including relevant optoelectronic parameters and important additional data (IEC 60904-3: 2008, ASTM G-173-03 global).
#
# | Material | Efficiency | V | J | FF | Bandgap | Area | Certified | Year | Comments |
# |----------|------------|---|---|----|---------|------|-----------|------|----------|
# |Sb$_{2}$Se$_{3}$ (substrate)| 9.2|0.400|32.6|70.3|1.18|0.26|Yes|2018|Hebei Key Laboratory of Optic-Electorninc Information Materials, Heibei Universirt, China.Substrate geometry structure incorporating core-shell nanowire approach. Aosorber deposited by CSS.|
# |Cu$_{2}$ZnSnS$_{4}$ (CZTS)| 11.0$\pm$0.2|0.731|21.74|69.3|1.5|0.2339|Yes|2017|UNSW. Abosrber prepared by sputtering Cu/ZnS/SnS|
# |Cu$_{2}$ZnSn(S$_{0.25}$Se$_{0.75}$)$_{4}$(CZTSSe)|12.6$\pm$0.3|0.513|35.2|69.8|1.13|0.4209|Yes|2013|IBM. Abosrber prepared by spin-coating a hydrazine-based solution.|
# |Cu$_{2}$ZnSn(S$_{y}$Se$_{1-y}$)$_{4}$(CZTSSe)| 12.62$\pm$0.29|0.541|35.35|65.9|NA|0.4804|Yes|2018|DGIST. Absorber prepared by sputting Sn/Cu/Zn and reactive annealing.|
# |Cu$_{2}$ZnSnSe$_{4}$ (CZTSe)|11.6|0.423|40.6|67.3|1.0|0.43|Yes|2015|IBM. Abosrber prepared by co-evaporation of Cu, Zn, Sn, and Se.|
# |Notable Exception|
# |Cu$_{2}$O|3.97|1.204|7.37|44.70|2.2|0.15|Yes|2014|Mit, Harvard University Cambridge and NREL. Electrochemical deposition.|
# |CsPbI$_{3}$|13.58|1.1626|15.246|76.63|NA|0.058|Yes|2017|NREL, University of Washington and University of Colorado. Couplied quantum dots films.|
# |SnS|4.36|0.372|20.2|58.0|1.1|0.24|Yes|2014|Department of Chemistry and Biology, Harvard University, Cambridge, USA. ALD deposition of absorber following by annealing H$_{2}$S|
# |Sb$_{2}$Se$_{3}$(superstrate)|7.6|0.420|29.9|60.4|1.18|0.091|Yes|2017|Sargent Join Research Center, Wuhan National Laboratory for Optoelectronics and SChool of Optical and Electronic Information, Huazhong University of Science and Technology, Wuhan, China. Vapor transport deposition|
# |Sb$_{2}$(S,Se)$_{3}$|9.9|0.650|24.07|63,5|1.53|0.0889|Yes|2019|University of Science and Technology of China, China. Spin coating and annealing.|
# |PbS|9.88|0.635|21.6|71.9|NA|0.05|Yes|2015|Wucha National Laboratory for Optoelectronics and School of Optical and Electronic Information, Huazhong University of Science and Technology, Wuhan, China. spin coating of PbS coloidal quantum dots.|
# |AgBiS$_{2}$|6.31|0.450|22.1|63.0|1.3|0.017|Yes|2016|ICFO-Institute de Ciencies Fotoniques. The Barcelona Institute of Science and Technology, Barcelona, Spain. Layer-by-layer spin coat deposition from nanocrystal solution.|

# %% [markdown]
# Table 2. List of non-certified single-junction record cells under global AM1.5 spectrum (1000 W/m$^{2}$)at 25$^{\circ}$ C, including relevant optoelectronic parameters, the means of verification and important additional data (IEC 60904-3: 2008, ASTM G-173-03 global). PC-Phtalocyanine.
#
# | Material | Efficiency | V | J | FF | Bandgap | Area | Certified | Year | Comments |
# |----------|------------|---|---|----|---------|------|-----------|------|----------|
# |Zn$_{3}$P$_{2}$|6.0|0.492|14.9|71.0|NA|0.70|No|1981|U.Delaware. CVT grown thick wafer absorber measured in AMI illumination. Measured under a simulated intensity of 87.5 mW/cm$^{2}$.|
# |CuSbSe$_{2}$|4.7|0.336|26.3|53.0|NA|0.2|No|2017|National Renewable Energy Laboratory, Golden, USA> Sputtering from binary Cu$_{2}$Se and Sb$_{2}$Se$_{3}$ targets.|
# |CuSbS$_{2}$|3.2|0.470|15.6|43.6|1.4-1.9|0.45|No|2016|New and Renewable Energy Research Division, Korea Institute of Energy Research, Daejeon, South Korea. Sulfurization of nanoparticle inks.|
# |Cu$_{2}$CdSnS$_{4}$|1.1|0.383|12.4|23.0|1.41|0.16|No|2015|NTU. Absorber prepared by spin-coating using 2-methoxyethanol-based solutuon.|
# |Cu$_{2}$ZnSnSe$_{4}$|11.8|0.463|38.3|66.3|1.05|0.522|No|2018|IREC, Spain: AIZT Japan: University of Barcelona, Spain: Martin-Luther-Universitiat Halle-Wittenberg, Germany. Sputtering of metallic precursors and reactive annealing. Ge doping(less than 0.5%)|
# |Cu$_{2}$BaSnS$_{4}$ (substrate)| 1.7|0.608|5.3|46.9|2.01|0.2|No|2018|Central South University, UNSW. Shen Zhen University, Xiamen University. Absorber prepared by spin-coating suing a 2-methoxyehanol-based solution.|
# |Cu$_{2}$BaSnS$_{4}$ (superstrate)|2.0|0.933|5.1|42.9|2.04|0.2|No|2017|The university of Toledo. Absorber prepared by sputtering method.|
# |Cu$_{2}$FeSnS$_{4}$|3.0|0.610|9.3|52.0|1.5|0.1|No|2017|Indian Association for the Vultivation of Sceince. Aboerber prepared by SILAR method|
# |Cu$_{2}$CdSn(S$_{0.xx}$Se$_{0.yy}$)$_{4}$|2.8|0.356|18.8|41.6|1.55|0.405|No|2015|Changchun Institute of Applied Chemistry, Chinese Academy of Sciences. Absorber prepared by spin-coating an ethanol, butyldithiocarbamic acid, and thioglycolic acid-based solution.|
# |Cu$_{2}$BaSn(S$_{0.xx}$Se$_{0.yy}$)$_{4}$|5.2|0.611|17.4|48.9|1.55|0.425|No|2017|Duke University, IBM. Aborber prepared by co-sputtering using Cu, Sn, and BaS|
# |Cu$_{2}$ZnGe(S$_{0.xx}$Se$_{0.yy}$)$_{4}$|6.0|0.617|NA|NA|1.47|0.25|No|2017|ZSW, CNRS. Absorber prepared by doctor-blade coating a DMF-based solution.|
# |Cu$_{2}$ZnGeSe$_{4}$|7.6|0.558|22.8|59.0|1.36|0.5|No|2018|CNRS, IMEC. Absorber prepared by souttering of Cu and Zn, and e-beam evaporation of Ge|
# |Ag$_{2}$ZnSnSe$_{4}$|5.18|0.504|21.0|48.7|1.35|0.45|No|2016|IBM, UCSD. Absorber prepared by coevaporation of Ag, Zn, Sn, and cracked Se.|
# |Cu$_{2}$(Zn$_{0.6}$Cd$_{0.4}$)SnS$_{4}$|11.0|0.650|25.5|66.1|1.38|0.22|No|2017|University of New South Wales, Australia; National Renewable Energy Laboratory, United Staes; Central South University, China. Sulfurized chemical bath deposited CdS on top of co-sputtered Cu/ZnS/SnS precursor.|
# |Ag$_{0.05-0.3}$Cu$_{0.95-0.7}$)$_{2}$ZnSn(S,Se)$_{4}$|11.2|0.464|36.2|66.5|Graded|0.21|No|2017|Henan University, China. Spin coating of ethanol based solution.|
# |(Ag$_{0.05}$Cu$_{0.95}$)$_{2}$(Zn$_{0.75}$Cd$_{0.25}$)Sn$_{4}$|10.1|0.650|23.4|66.2|1.4|0.16|No|2018|NTU, Singapore; HZB, Germany. Spin coating of 2-methoxyethanol based solution.|
# |Cu$_{2}$Zn(Sn$_{0.78}$Ge$_{0.22}$Se$_{4}$|12.3|0.527|32.2|72.7|1.11|0.519|No|2016|AIST, Japan. Co-evaporation and reactive annealing.|
# |(Li$_{0.06}$Cu$_{0.94}$)$_{2}$ZnSn(S,Se)$_{4}$|11.6|0.531|33.7|64.8|1.13|0.285|No|2018|EMPA, Switzerland; Universidad Autonoma de Madrid, Spain; HZB, Germany. Spin coating of DMSO based solution|
# |Cu$_{2}$(Zn$_{0.95}$Mn$_{0.05}$Sn(S,Se)$_{4}$|8.9|0.418|33.7|63.3|1.06|0.34|No|2018|Nankai University, China; ational Institute of Material Science, Japan. Spin coating of 2-methoxyethanol based solution.|
# |:Notable Expection:|
# |Cu$_{2}$O|8.1|1.2|10.4|65.0|2.2|0.03|No|2013|Kanazawa I. T. Cu$_{2}$O sheets oxidized from Cu foils|
# |Bi$_{2}$FeCrO$_{6}$|8.1|0.84|20.6|46.0|1.5|NA|No|2015|INRS Canada. PLD absorber with 3-layer stack.|
# |InP|7.3|0.57|17.4|73.0|1.32|0.0625|No|2015|Purdur U., The U. of California and Pennsylvania State U. Pulsed laser deposition.|
# |(In,Ga)N|3.0|1.8|2.6|64.0|NA|0.046|No|2010|Texas Tech. MOCVD MQW absorber.|
# |ZnSnN$_{2}$|1.5|0.36|7.5|57.0|1.4|0.06|No|2018|Ninbo, China. Sputtered absorber.|
# |Bil$_{3}$|1.2|0.607|5.3|37.6|1.72|0.04|No|2018|U. Bristol. Spin coating of Bi(NO$_{3}$)$_{3}$ and thiourea, followed by thermolysis at 200$^{\circ}$ C to produce a homogeneous Bi$_{2}$S$_{3}$ film that is subsequently iodinated upon exposure to the I$_{2}$ gas.|
# |CsPbBr$_{3}$|8.8|1.310|8.2|81.4|2.32|0.071|No|2019|Huazhong U. Science and Technology. Multi-step solution process method.|
# |CsPbl$_{3}$|15.7|1.08|18.4|79.3|1.73|0.108|No|2018|Chinese Academy of Science. Spin coating and soft annealing.|
# |CsPbl$_{2}$Br|16.1|1.23|16.8|77.8|N.R.|0.1|No|2019|Soochow University and Chinese Aademy of Science. Spin coating|
# |CsPbIBr$_{2}$|9.2|1.245|10.7|69.0|2.05|0.09|No|2018|Xidian U. Precursor solution by spin coating. The JV curvers present hysteresis.|
# |CsPb$_{0.95}$Eu$_{0.05}$I$_{2}$Br|13.7|1.22|14.6|76.6|1.92|0.16|No|2018|Wuhan U. Technology EPFL, Nankai U. Precursor solution by spin coating. Some hysteresis is observed.|
# |CsSnBr$_{3}$|2.2|0.42|9.1|57.0|1.75|NA|No|2016|Weizmann Institute of Science. Spin coating. The EQE integration gives 2 ma/cm$^{2}$ less current density.|
# |CsSnI$_{3}$|4.8|0.382|25.7|49.1|1.30|~0.15|No|2017|Northwestern University and Mitsubishi Chemical Group Science & Technology Research Center. Spin coating with hydrazine. Integrated EQE gives J$_{sc}$ of approzimately 24 ma/cm$^{2}$.|
# |CsSn$_{0.5}$Ge$_{0.5}$I$_{3}$|7.1|0.63|18.6|60.6|1.50|0.1|No|2018|Brown U., U. of Nebraska-Lincoln, Worcester Polytechnic Institute, and Okinawa Institute of Science and Technology Graduate University. Powder synthesized by solide-state reaction and thermally evaporated.|
# |Se|6.5|0.969|10.6|63.4|1.95|0.027|No|2017|IBM Thomas J. Watson Research Centre, Yorktown Heights, USA. Thermal evaporation of Se at room temperature followed by post deposition annealing.|
# |GeSe|1.5|0.240|14.5|42.6|1.1-1.2|0.09|No|2017|Beijing National Laboratory for Molecular Sciences, Key Laboratory of Molecular Nanostructure and Nanotechnology, Institute of Chemistry, Beijing, China. Rapid termal sublimation.|
# |Sb$_{2}$S$_{3}$| 7.5|0.711|16.1|65.0|1.7|0.16|No|2014|Division of Advaned Materials, Korea Institute of Chemical Technology, Daegon, Repubilc of Korea. Chemical bath depositon followed by additional sulfurization.|
# |Sb$_{2}$(S$_{x}$Se$_{1-x}$)$_{3}$|6.6|0.475|24.9|55.6|1.3-1.7|0.12|No|2014|Division of Advanced Materials, Korea Institute of Chemical Technology, Daejeon, Republi of Korera. Combination of spin coating and chemical bath deposition.|
# |Bi$_{2}$S$_{3}$|3.3|0.700|10.7|45.0|1.2|0.18|No|2015|Department of Chemical and Biological Engineering, Princeton University. USA. Percolated Bi$_{2}$S$_{3}$ network with P3HT.|
# |Cu$_{2}$CdGeSe$_{4}$|4.2|0.464|23.3|39.0|12.7|0.02|No|2018|Tallinn University of Technology. Absorber prepared by molten salt method using CdI$_{2}$ and KI as fluxes. Monograin-based device.|

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
sb2se3=[9.2,1.18]
cu2znsns4=[11,1.5]
cu2znsns025se075_4=[12.6,1.13]
cu2znsnse_4=[11.6,1.0]
cu2o=[3.97,2.2]
sns=[4.36,1.1]
sb2se3_sat=[7.6,1.18]
sb2s_se3=[9.9,1.53]
agbis2=[6.31,1.3]

# %%
xarray_certified=np.array([9.2,11,12.6,11.6,3.97,4.36,7.6,9.9,6.31])
yarray_certified=np.array([1.18,1.5,1.13,1.0,2.2,1.1,1.18,1.53,1.3])
certified_names=['Sb$_{2}$Se$_{3}$','Cu$_{2}$ZnSnS${4}$','Cu$_{2}$ZnSn(S$_{0.25}$,Se$_{0.75}$)$_{4}$','Cu$_{2}$ZnSnSe$_{4}$','Cu$_{2}$O','SnS','Sb$_{2}$Se$_{3}$','Sb$_{2}$(S,Se)$_{3}$','AgBiS$_{2}$']

# %%
plt.figure() #New figure
plt.plot(sb2se3[1],sb2se3[0],'k.',label='Sb$_{2}$Se$_{3}$')
plt.text(sb2se3[1]+0.03,sb2se3[0]+0.03, 'Sb$_{2}$Se$_{3}$', fontsize=5)
plt.plot(cu2znsns4[1],cu2znsns4[0],'k.',label='Cu$_{2}$ZnSnS${4}$')
plt.text(cu2znsns4[1]+0.03,cu2znsns4[0]+0.03, 'Cu$_{2}$ZnSnS${4}$', fontsize=5)
plt.plot(cu2znsns025se075_4[1],cu2znsns025se075_4[0],'k.',label='Cu$_{2}$ZnSn(S$_{0.25}$,Se$_{0.75}$)$_{4}$')
plt.text(cu2znsns025se075_4[1]+0.03,cu2znsns025se075_4[0]+0.03, 'Cu$_{2}$ZnSn(S$_{0.25}$,Se$_{0.75}$)$_{4}$', fontsize=5)
plt.plot(cu2znsnse_4[1],cu2znsnse_4[0],'k.',label='Cu$_{2}$ZnSnSe$_{4}$')
plt.text(cu2znsnse_4[1]+0.03,cu2znsnse_4[0]+0.03, 'Cu$_{2}$ZnSnSe$_{4}$', fontsize=5)
plt.plot(cu2o[1],cu2o[0],'k.',label='Cu$_{2}$O')
plt.text(cu2o[1]-0.1,cu2o[0]+0.03, 'Cu$_{2}$O', fontsize=5)
plt.plot(sns[1],sns[0],'k.',label='SnS')
plt.text(sns[1]+0.03,sns[0]+0.03, 'SnS', fontsize=5)
plt.plot(sb2se3_sat[1],sb2se3_sat[0],'k.',label='Sb$_{2}$Se$_{3}$ (supersaturate)')
plt.text(sb2se3_sat[1]+0.03,sb2se3_sat[0]+0.03, 'Sb$_{2}$Se$_{3}$ (supersaturate)', fontsize=5)
plt.plot(sb2s_se3[1],sb2s_se3[0],'k.',label='Sb$_{2}$(S,Se)$_{3}$')
plt.text(sb2s_se3[1]+0.03,sb2s_se3[0]+0.03, 'Sb$_{2}$(S,Se)$_{3}$', fontsize=5)
plt.plot(agbis2[1],agbis2[0],'k.',label='AgBiS$_{2}$')
plt.text(agbis2[1]+0.03,agbis2[0]+0.03, 'AgBiS$_{2}$', fontsize=5)
plt.title('certified single-juction record cell')
plt.xlabel('bandgap')
plt.ylabel('efficiency')
plt.grid(True)
plt.savefig("certified single-junction record cell",dpi=300)

# %%
plt.figure() #New figure
for i,certified_name in enumerate(certified_names):
    x = xarray_certified[i]
    y = yarray_certified[i]
    plt.plot(x, y,'k.')
    plt.text(x+0.03, y+0.03, certified_name, fontsize=9)
    plt.title('certified single-juction record cell')
plt.show()

# %%
cusbs2=[3.2,np.arange(1.4,1.9)]
cu2cdsns4=[1.1,1.41]
cu2znsnse4=[11.8,1.05]
cu2basns4_substrate=[1.7,2.01]
cu2basns4_superstrate=[2.0,2.04]
cu2fesns4=[2.0,1.5]
cu2cdsnsxxseyy_4=[2.8,1.55]
cu2basnsxxseyy_4=[5.2,1.55]
cu2zngesxxseyy_4=[6.0,1.47]
cu2zngese4=[7.6,1.36]
ag2znsnse4=[5.18,1.35]
cu2zn06cd04sns4=[11.0,1.38]
agcuzncdsn4=[10.1,1.4]
cu2znsngese4=[12.3,1.11]
li006cu0942zbsbsse4=[11.6,1.13]
cu2zn095mn005snsse4=[8.9,1.06]
cu2o_1=[8.1,2.2]
bi2fecro6=[8.1,1.4]
inp=[7.3,1.32]
znsnn2=[1.5,1.4]
bii3=[1.2,1.72]
cspbbr3=[8.8,2.32]
cspbi3=[15.7,1.73]
cspbibr2=[9.2,2.05]
cspb095eu005i2br=[13.7,1.92]
cssnbr3=[2.2,1.75]
cssni3=[4.8,1.30]
cssn05ge05i3=[7.1,1.5]
se=[6.5,1.95]
gese=[1.5,np.arange(1.1,1.2)]
sb2s3=[7.5,1.7]
sb2sxse1_x_3=[6.6,np.arange(1.3,1.7)]
bi2s3=[3.3,1.2]
cu2cdgese4=[4.2,1.27]

# %%
plt.figure() #New figure
plt.plot(cusbs2[1],cusbs2[0],'k.',label='CuSbS$_{2}$')
plt.text(cusbs2[1]+0.03,cusbs2[0]+0.03, 'CuSbS$_{2}$', fontsize=5)

plt.plot(cu2cdsns4[1],cu2cdsns4[0],'k.',label='Cu$_{2}$CdSnS$_{4}$')
plt.text(cu2cdsns4[1]+0.03,cu2cdsns4[0]+0.03, 'Cu$_{2}$CdSnS$_{4}$', fontsize=5)

plt.plot(cu2znsnse4[1],cu2znsnse4[0],'k.',label='Cu$_{2}$ZnSnSe$_{4}$')
plt.text(cu2znsnse4[1]+0.03,cu2znsnse4[0]+0.03, 'Cu$_{2}$ZnSnSe$_{4}$', fontsize=5)

plt.plot(cu2basns4_substrate[1],cu2basns4_substrate[0],'k.',label='Cu$_{2}$BaSnS$_{4}$ (substrate)')
plt.text(cu2basns4_substrate[1]-0.2,cu2basns4_substrate[0]+0.03, 'Cu$_{2}$BaSnS$_{4}$ (substrate)', fontsize=5)

plt.plot(cu2basns4_superstrate[1],cu2basns4_superstrate[0],'k.',label='Cu$_{2}$BaSnS$_{4}$ (superstrate)')
plt.text(cu2basns4_superstrate[1]-0.2,cu2basns4_superstrate[0]+0.2, 'Cu$_{2}$BaSnS$_{4}$ (superstrate)', fontsize=5)

plt.plot(cu2fesns4[1],cu2fesns4[0],'k.',label='Cu$_{2}$FeSnS$_{4}$')
plt.text(cu2fesns4[1]+0.03,cu2fesns4[0]+0.03, 'Cu$_{2}$FeSnS$_{4}$', fontsize=5)

plt.plot(cu2cdsnsxxseyy_4[1],cu2cdsnsxxseyy_4[0],'k.',label='Cu$_{2}$CdSn(S$_{0.xx}$Se$_{0.yy}$)$_{4}$')
plt.text(cu2cdsnsxxseyy_4[1]+0.03,cu2cdsnsxxseyy_4[0]+0.03, 'Cu$_{2}$CdSn(S$_{0.xx}$Se$_{0.yy}$)$_{4}$', fontsize=5)

plt.plot(cu2basnsxxseyy_4[1],cu2basnsxxseyy_4[0],'k.',label='Cu$_{2}$BaSn(S$_{0.xx}$Se$_{0.yy}$)$_{4}$')
plt.text(cu2basnsxxseyy_4[1]+0.03,cu2basnsxxseyy_4[0]+0.03, 'Cu$_{2}$BaSn(S$_{0.xx}$Se$_{0.yy}$)$_{4}$', fontsize=5)

plt.plot(cu2zngesxxseyy_4[1],cu2zngesxxseyy_4[0],'k.',label='Cu$_{2}$ZnGe(S$_{0.xx}$Se$_{0.yy}$)$_{4}$')
plt.text(cu2zngesxxseyy_4[1]+0.03,cu2zngesxxseyy_4[0]+0.03, 'Cu$_{2}$ZnGe(S$_{0.xx}$Se$_{0.yy}$)$_{4}$', fontsize=5)

plt.plot(cu2zngese4[1],cu2zngese4[0],'k.',label='Cu$_{2}$ZnGeSe$_{4}$')
plt.text(cu2zngese4[1]+0.03,cu2zngese4[0]+0.03, 'Cu$_{2}$ZnGeSe$_{4}$', fontsize=5)

plt.plot(ag2znsnse4[1],ag2znsnse4[0],'k.',label='Ag$_{2}$ZnSnSe$_{4}$')
plt.text(ag2znsnse4[1]+0.03,ag2znsnse4[0]+0.03, 'Ag$_{2}$ZnSnSe$_{4}$', fontsize=5)

plt.plot(cu2zn06cd04sns4[1],cu2zn06cd04sns4[0],'k.',label='Cu$_{2}$(Zn$_{0.6}$Cd$_{0.4}$)SnS$_{4}$')
plt.text(cu2zn06cd04sns4[1]+0.03,cu2zn06cd04sns4[0]+0.03, 'Cu$_{2}$(Zn$_{0.6}$Cd$_{0.4}$)SnS$_{4}$', fontsize=5)

plt.plot(agcuzncdsn4[1],agcuzncdsn4[0],'k.',label='(Ag$_{0.05}$Cu$_{0.95}$)$_{2}$(Zn$_{0.75}$Cd$_{0.25}$)Sn$_{4}$')
plt.text(agcuzncdsn4[1]+0.03,agcuzncdsn4[0]+0.03, '(Ag$_{0.05}$Cu$_{0.95}$)$_{2}$(Zn$_{0.75}$Cd$_{0.25}$)Sn$_{4}$', fontsize=5)

plt.plot(cu2znsngese4[1],cu2znsngese4[0],'k.',label='Cu$_{2}$Zn(Sn$_{0.78}$Ge$_{0.22}$Se$_{4}$')
plt.text(cu2znsngese4[1]+0.03,cu2znsngese4[0]+0.03, 'Cu$_{2}$Zn(Sn$_{0.78}$Ge$_{0.22}$Se$_{4}$', fontsize=5)

plt.plot(li006cu0942zbsbsse4[1],li006cu0942zbsbsse4[0],'k.',label='(Li$_{0.06}$Cu$_{0.94}$)$_{2}$ZnSn(S,Se)$_{4}$')
plt.text(li006cu0942zbsbsse4[1]+0.03,li006cu0942zbsbsse4[0]-0.3, '(Li$_{0.06}$Cu$_{0.94}$)$_{2}$ZnSn(S,Se)$_{4}$', fontsize=5)

plt.plot(cu2zn095mn005snsse4[1],cu2zn095mn005snsse4[0],'k.',label='Cu$_{2}$(Zn$_{0.95}$Mn$_{0.05}$Sn(S,Se)$_{4}$')
plt.text(cu2zn095mn005snsse4[1]+0.03,cu2zn095mn005snsse4[0]+0.03, 'Cu$_{2}$(Zn$_{0.95}$Mn$_{0.05}$Sn(S,Se)$_{4}$', fontsize=5)


plt.title('non-certified single-juction record cell')
plt.xlabel('bandgap')
plt.ylabel('efficiency')
plt.grid(True)
plt.savefig("non-certified single-junction record cell",dpi=300)

# %%
plt.plot(cu2o_1[1],cu2o_1[0],'k.',label='Cu$_{2}O$')
plt.text(cu2o_1[1]+0.03,cu2o_1[0]+0.03, 'CuS$_{2}$O', fontsize=5)

plt.plot(bi2fecro6[1],bi2fecro6[0],'k.',label='Bi$_{2}$FeCrO$_{6}$')
plt.text(bi2fecro6[1]+0.03,bi2fecro6[0]+0.03, 'Bi$_{2}$FeCrO$_{6}$', fontsize=5)

plt.plot(inp[1],inp[0],'k.',label='InP')
plt.text(inp[1]+0.03,inp[0]+0.03, 'InP', fontsize=5)

plt.plot(znsnn2[1],znsnn2[0],'k.',label='ZnSnN$_{2}$')
plt.text(znsnn2[1]+0.03,znsnn2[0]+0.03, 'ZnSnN$_{2}$', fontsize=5)

plt.plot(bii3[1],bii3[0],'k.',label='BiI$_{3}$')
plt.text(bii3[1]+0.03,bii3[0]+0.03, 'BiI$_{3}$', fontsize=5)

plt.plot(cspbbr3[1],cspbbr3[0],'k.',label='CsPbBr$_{3}$')
plt.text(cspbbr3[1]-0.03,cspbbr3[0]+0.3, 'CsPbBr$_{3}$', fontsize=5)

plt.plot(cspbi3[1],cspbi3[0],'k.',label='CsPbI$_{3}$')
plt.text(cspbi3[1]+0.03,cspbi3[0]+0.03, 'CsPbI$_{3}$', fontsize=5)

plt.plot(cspbibr2[1],cspbibr2[0],'k.',label='BiI$_{3}$')
plt.text(cspbibr2[1]+0.03,cspbibr2[0]+0.03, 'BiI$_{3}$', fontsize=5)

plt.plot(cspb095eu005i2br[1],cspb095eu005i2br[0],'k.',label='CsPb$_{0.95}$Eu$_{0.05}$I$_{2}$Br')
plt.text(cspb095eu005i2br[1]+0.03,cspb095eu005i2br[0]+0.03, 'CsPb$_{0.95}$Eu$_{0.05}$I$_{2}$Br', fontsize=5)

plt.plot(cssnbr3[1],cssnbr3[0],'k.',label='CsSnBr$_{3}$')
plt.text(cssnbr3[1]+0.03,cssnbr3[0]+0.03, 'CsSnBr$_{3}$', fontsize=5)

plt.plot(cssni3[1],cssni3[0],'k.',label='CsSnI$_{3}$')
plt.text(cssni3[1]+0.03,cssni3[0]+0.03, 'CsSnI$_{3}$', fontsize=5)

plt.plot(cssn05ge05i3[1],cssn05ge05i3[0],'k.',label='CsSn$_{0.5}$Ge$_{0.5}$I$_{3}$')
plt.text(cssn05ge05i3[1]+0.03,cssn05ge05i3[0]+0.03, 'CsSn$_{0.5}$Ge$_{0.5}$I$_{3}$', fontsize=5)

plt.plot(se[1],se[0],'k.',label='Se')
plt.text(se[1]+0.03,se[0]+0.03, 'Se', fontsize=5)

plt.plot(gese[1],gese[0],'k.',label='GeSe')
plt.text(gese[1]+0.03,gese[0]+0.03, 'GeSe', fontsize=5)

plt.plot(sb2s3[1],sb2s3[0],'k.',label='Sb$_{2}$S$_{3}$')
plt.text(sb2s3[1]+0.03,sb2s3[0]+0.03, 'Sb$_{2}$S$_{3}$', fontsize=5)

plt.plot(gese[1],gese[0],'k.',label='GeSe')
plt.text(gese[1]+0.03,gese[0]+0.03, 'GeSe', fontsize=5)

plt.plot(sb2sxse1_x_3[1],sb2sxse1_x_3[0],'k.',label='Sb$_{2}$(S$_{x}$Se$_{1-x}$)$_{3}$')
plt.text(sb2sxse1_x_3[1]+0.03,sb2sxse1_x_3[0]+0.03, 'Sb$_{2}$(S$_{x}$Se$_{1-x}$)$_{3}$', fontsize=5)

plt.plot(bi2s3[1],bi2s3[0],'k.',label='Bi$_{2}$S$_{3}$')
plt.text(bi2s3[1]+0.03,bi2s3[0]+0.03, 'Bi$_{2}$S$_{3}$', fontsize=5)

plt.plot(cu2cdgese4[1],cu2cdgese4[0],'k.',label='Cu$_{2}$CdGeSe$_{4}$')
plt.text(cu2cdgese4[1]+0.03,cu2cdgese4[0]+0.03, 'Cu$_{2}$CdGeSe$_{4}$', fontsize=5)

plt.title('notable exception of non-certified single-juction record cell')
plt.xlabel('bandgap')
plt.ylabel('efficiency')
plt.grid(True)
plt.savefig("notable exception of non-certified single-junction record cell",dpi=300)
